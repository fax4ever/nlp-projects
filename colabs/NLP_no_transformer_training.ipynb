# %% [markdown]
# # NLP no-Transformer: Training

# %%
# !pip install Wikidata
# !pip install datasets
# Out:
# Collecting Wikidata
#   Downloading Wikidata-0.8.1-py3-none-any.whl.metadata (3.0 kB)
# Downloading Wikidata-0.8.1-py3-none-any.whl (29 kB)
# Installing collected packages: Wikidata
# Successfully installed Wikidata-0.8.1
# Collecting datasets
#   Downloading datasets-3.5.1-py3-none-any.whl.metadata (19 kB)
# Requirement already satisfied: filelock in /usr/local/lib/python3.11/dist-packages (from datasets) (3.18.0)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.11/dist-packages (from datasets) (2.0.2)
# Requirement already satisfied: pyarrow>=15.0.0 in /usr/local/lib/python3.11/dist-packages (from datasets) (18.1.0)
# Collecting dill<0.3.9,>=0.3.0 (from datasets)
#   Downloading dill-0.3.8-py3-none-any.whl.metadata (10 kB)
# Requirement already satisfied: pandas in /usr/local/lib/python3.11/dist-packages (from datasets) (2.2.2)
# Requirement already satisfied: requests>=2.32.2 in /usr/local/lib/python3.11/dist-packages (from datasets) (2.32.3)
# Requirement already satisfied: tqdm>=4.66.3 in /usr/local/lib/python3.11/dist-packages (from datasets) (4.67.1)
# Collecting xxhash (from datasets)
#   Downloading xxhash-3.5.0-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (12 kB)
# Collecting multiprocess<0.70.17 (from datasets)
#   Downloading multiprocess-0.70.16-py311-none-any.whl.metadata (7.2 kB)
# Collecting fsspec<=2025.3.0,>=2023.1.0 (from fsspec[http]<=2025.3.0,>=2023.1.0->datasets)
#   Downloading fsspec-2025.3.0-py3-none-any.whl.metadata (11 kB)
# Requirement already satisfied: aiohttp in /usr/local/lib/python3.11/dist-packages (from datasets) (3.11.15)
# Requirement already satisfied: huggingface-hub>=0.24.0 in /usr/local/lib/python3.11/dist-packages (from datasets) (0.30.2)
# Requirement already satisfied: packaging in /usr/local/lib/python3.11/dist-packages (from datasets) (24.2)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.11/dist-packages (from datasets) (6.0.2)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp->datasets) (2.6.1)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.11/dist-packages (from aiohttp->datasets) (1.3.2)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp->datasets) (25.3.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.11/dist-packages (from aiohttp->datasets) (1.6.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.11/dist-packages (from aiohttp->datasets) (6.4.3)
# Requirement already satisfied: propcache>=0.2.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp->datasets) (0.3.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp->datasets) (1.20.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.11/dist-packages (from huggingface-hub>=0.24.0->datasets) (4.13.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests>=2.32.2->datasets) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests>=2.32.2->datasets) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests>=2.32.2->datasets) (2.4.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests>=2.32.2->datasets) (2025.1.31)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.11/dist-packages (from pandas->datasets) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.11/dist-packages (from pandas->datasets) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.11/dist-packages (from pandas->datasets) (2025.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.11/dist-packages (from python-dateutil>=2.8.2->pandas->datasets) (1.17.0)
# Downloading datasets-3.5.1-py3-none-any.whl (491 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 491.4/491.4 kB 14.1 MB/s eta 0:00:00
# Downloading dill-0.3.8-py3-none-any.whl (116 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 116.3/116.3 kB 7.8 MB/s eta 0:00:00
# Downloading fsspec-2025.3.0-py3-none-any.whl (193 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 193.6/193.6 kB 12.7 MB/s eta 0:00:00
# Downloading multiprocess-0.70.16-py311-none-any.whl (143 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 143.5/143.5 kB 10.3 MB/s eta 0:00:00
# Downloading xxhash-3.5.0-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (194 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 194.8/194.8 kB 14.4 MB/s eta 0:00:00
# Installing collected packages: xxhash, fsspec, dill, multiprocess, datasets
#   Attempting uninstall: fsspec
#     Found existing installation: fsspec 2025.3.2
#     Uninstalling fsspec-2025.3.2:
#       Successfully uninstalled fsspec-2025.3.2
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# gcsfs 2025.3.2 requires fsspec==2025.3.2, but you have fsspec 2025.3.0 which is incompatible.
# torch 2.6.0+cu124 requires nvidia-cublas-cu12==12.4.5.8; platform_system == "Linux" and platform_machine == "x86_64", but you have nvidia-cublas-cu12 12.5.3.2 which is incompatible.
# torch 2.6.0+cu124 requires nvidia-cuda-cupti-cu12==12.4.127; platform_system == "Linux" and platform_machine == "x86_64", but you have nvidia-cuda-cupti-cu12 12.5.82 which is incompatible.
# torch 2.6.0+cu124 requires nvidia-cuda-nvrtc-cu12==12.4.127; platform_system == "Linux" and platform_machine == "x86_64", but you have nvidia-cuda-nvrtc-cu12 12.5.82 which is incompatible.
# torch 2.6.0+cu124 requires nvidia-cuda-runtime-cu12==12.4.127; platform_system == "Linux" and platform_machine == "x86_64", but you have nvidia-cuda-runtime-cu12 12.5.82 which is incompatible.
# torch 2.6.0+cu124 requires nvidia-cudnn-cu12==9.1.0.70; platform_system == "Linux" and platform_machine == "x86_64", but you have nvidia-cudnn-cu12 9.3.0.75 which is incompatible.
# torch 2.6.0+cu124 requires nvidia-cufft-cu12==11.2.1.3; platform_system == "Linux" and platform_machine == "x86_64", but you have nvidia-cufft-cu12 11.2.3.61 which is incompatible.
# torch 2.6.0+cu124 requires nvidia-curand-cu12==10.3.5.147; platform_system == "Linux" and platform_machine == "x86_64", but you have nvidia-curand-cu12 10.3.6.82 which is incompatible.
# torch 2.6.0+cu124 requires nvidia-cusolver-cu12==11.6.1.9; platform_system == "Linux" and platform_machine == "x86_64", but you have nvidia-cusolver-cu12 11.6.3.83 which is incompatible.
# torch 2.6.0+cu124 requires nvidia-cusparse-cu12==12.3.1.170; platform_system == "Linux" and platform_machine == "x86_64", but you have nvidia-cusparse-cu12 12.5.1.3 which is incompatible.
# torch 2.6.0+cu124 requires nvidia-nvjitlink-cu12==12.4.127; platform_system == "Linux" and platform_machine == "x86_64", but you have nvidia-nvjitlink-cu12 12.5.82 which is incompatible.
# Successfully installed datasets-3.5.1 dill-0.3.8 fsspec-2025.3.0 multiprocess-0.70.16 xxhash-3.5.0

# %%
import torch, random, requests, os, pickle
import numpy as np
from wikidata.client import Client
from datasets import load_dataset
from itertools import islice
from google.colab import userdata

# %% [markdown]
# Setting seeds to try to make the training as much deterministic as possible.
# This should help to compare results (for the instance accuracy of the validation test) of different trainings.

# %%
torch.manual_seed(42)
random.seed(42)
np.random.seed(42)

# %% [markdown]
# Wikipedia pages and Wikidata data need to be loaded from the web.
# In order to speed up the training and the inference, we store (cache) the retrieved and the processed data in files.

# %%
def dump(file_name, result):
    # remove dump files if present
    if os.path.exists(file_name):
        os.remove(file_name)
    with open(file_name, 'wb') as file:
        print("dumping", file_name)
        # noinspection PyTypeChecker
        pickle.dump(result, file)

def load(file_name):
    with open(file_name, 'rb') as file:
        print("loading", file_name)
        # noinspection PyTypeChecker
        return pickle.load(file)

# %% [markdown]
# In this section we build the singleton `NLPDataset`, that contains:
# 1. The original Hugging Face dataset
# 2. The Wikidata entities
# 3. The Wikipedia pages

# %%
def wikipedia_pages(sitelinks):
    result = []
    for site_key in sitelinks.keys():
        if site_key.endswith("wiki") and not site_key.startswith("commons"):
            lang = site_key.replace("wiki", "")
            result.append(lang)
    return result

def build_claims(claims):
    result = {}
    for prop_id, values in claims.items():
        result[prop_id] = len(values)
    return result

class Entity:
    def __init__(self, entity_id, dataset_item, wiki_data, wiki_text):
        self.entity_id = entity_id
        self.label = dataset_item['label']
        self.name = dataset_item['name']
        self.description = dataset_item['description']
        self.type = dataset_item['type']
        self.category = dataset_item['category']
        self.subcategory = dataset_item['subcategory']
        self.wiki_text = wiki_text
        # Languages
        self.labels = list(wiki_data.data.get("labels", {}).keys())
        self.descriptions = list(wiki_data.data.get("descriptions", {}).keys())
        self.aliases = list(wiki_data.data.get("aliases", {}).keys())
        self.wikipedia_pages = wikipedia_pages(wiki_data.data.get("sitelinks", {}))
        # Properties
        self.claims = build_claims(wiki_data.data.get("claims", {}))

    def __str__(self):
        return self.entity_id + ": " + self.label + " - " + self.name

API_URL = "https://en.wikipedia.org/w/api.php"

def extract_entity_id(url):
    return url.strip().split("/")[-1]

def get_wiki_text(en_wiki):
    if not en_wiki:
        return None
    title = en_wiki["title"]
    params = {
        "action": "query",
        "prop": "extracts",
        "explaintext": True,
        "titles": title,
        "format": "json",
        "redirects": 1
    }
    headers = {'User-Agent': 'Mozilla/5.0 (Windows NT 6.2; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/75.0.3770.100 Safari/537.36'}
    res = requests.get(API_URL, params=params, headers=headers)
    json = res.json()
    page = next(iter(json["query"]["pages"].values()))
    # Keep the original text as it is.
    # The text will be processed in other methods,
    # such as processed_dataset#tokenize().
    return page.get("extract", "")

class EntityFactory:
    def __init__(self, client):
        self.client = client

    def create(self, item):
        entity_id = extract_entity_id(item['item'])
        try:
            wikidata = self.client.get(entity_id, load=True)
            sitelinks = wikidata.data.get("sitelinks", {})
            en_wiki = sitelinks.get("enwiki")
            return Entity(entity_id, item, wikidata, get_wiki_text(en_wiki))
        except Exception as e:
            print("Error loading id:", entity_id, e)
            return None

TRAINING_FILE_NAME = "training.bin"
VALIDATION_FILE_NAME = "validation.bin"

def create_set(dataset, factory, limit, file_name):
    # apply the limits
    if limit is None:
        limit = len(dataset)
    result = []
    for index, item in enumerate(islice(dataset, limit)):
        created = factory.create(item)
        if created is not None:
            result.append(created)
        if (index + 1) % 10 == 0:
            print("creating", file_name, index + 1, "/", limit)
    return result

class NLPDataset:
    def __init__(self, training_limit=None, validation_limit=None, force_reload=False):
        if not (os.path.exists(TRAINING_FILE_NAME)) or not (os.path.exists(VALIDATION_FILE_NAME)) or force_reload:
            # load the project dataset
            dataset = load_dataset('sapienzanlp/nlp2025_hw1_cultural_dataset', token=userdata.get('HF_TOKEN'))
            # a factory object is used to create our entities
            factory = EntityFactory(Client())

            self.training_set = create_set(dataset['train'], factory, training_limit, TRAINING_FILE_NAME)
            self.validation_set = create_set(dataset['validation'], factory, validation_limit, VALIDATION_FILE_NAME)
            dump(TRAINING_FILE_NAME, self.training_set)
            dump(VALIDATION_FILE_NAME, self.validation_set)
        else:
            # by default load the dataset from a local dump
            self.training_set = load(TRAINING_FILE_NAME)
            self.validation_set = load(VALIDATION_FILE_NAME)

    def __str__(self):
        return "training: " + str(len(self.training_set)) + ". validation: " + str(len(self.validation_set))

# %%
nlp_dataset = NLPDataset()
# Out:
# README.md:   0%|          | 0.00/2.31k [00:00<?, ?B/s]
# train.csv:   0%|          | 0.00/946k [00:00<?, ?B/s]
# valid.csv:   0%|          | 0.00/45.9k [00:00<?, ?B/s]
# Generating train split:   0%|          | 0/6251 [00:00<?, ? examples/s]
# Generating validation split:   0%|          | 0/300 [00:00<?, ? examples/s]
# creating training.bin 10 / 6251
# creating training.bin 20 / 6251
# creating training.bin 30 / 6251
# creating training.bin 40 / 6251
# creating training.bin 50 / 6251
# creating training.bin 60 / 6251
# creating training.bin 70 / 6251
# creating training.bin 80 / 6251
# creating training.bin 90 / 6251
# creating training.bin 100 / 6251
# creating training.bin 110 / 6251
# creating training.bin 120 / 6251
# creating training.bin 130 / 6251
# creating training.bin 140 / 6251
# creating training.bin 150 / 6251
# creating training.bin 160 / 6251
# creating training.bin 170 / 6251
# creating training.bin 180 / 6251
# creating training.bin 190 / 6251
# creating training.bin 200 / 6251
# creating training.bin 210 / 6251
# creating training.bin 220 / 6251
# creating training.bin 230 / 6251
# creating training.bin 240 / 6251
# creating training.bin 250 / 6251
# creating training.bin 260 / 6251
# creating training.bin 270 / 6251
# creating training.bin 280 / 6251
# creating training.bin 290 / 6251
# creating training.bin 300 / 6251
# creating training.bin 310 / 6251
# creating training.bin 320 / 6251
# creating training.bin 330 / 6251
# creating training.bin 340 / 6251
# creating training.bin 350 / 6251
# creating training.bin 360 / 6251
# creating training.bin 370 / 6251
# creating training.bin 380 / 6251
# creating training.bin 390 / 6251
# creating training.bin 400 / 6251
# creating training.bin 410 / 6251
# creating training.bin 420 / 6251
# creating training.bin 430 / 6251
# creating training.bin 440 / 6251
# creating training.bin 450 / 6251
# creating training.bin 460 / 6251
# creating training.bin 470 / 6251
# creating training.bin 480 / 6251
# creating training.bin 490 / 6251
# creating training.bin 500 / 6251
# creating training.bin 510 / 6251
# creating training.bin 520 / 6251
# creating training.bin 530 / 6251
# creating training.bin 540 / 6251
# creating training.bin 550 / 6251
# creating training.bin 560 / 6251
# creating training.bin 570 / 6251
# creating training.bin 580 / 6251
# creating training.bin 590 / 6251
# creating training.bin 600 / 6251
# creating training.bin 610 / 6251
# creating training.bin 620 / 6251
# creating training.bin 630 / 6251
# creating training.bin 640 / 6251
# creating training.bin 650 / 6251
# creating training.bin 660 / 6251
# creating training.bin 670 / 6251
# creating training.bin 680 / 6251
# creating training.bin 690 / 6251
# creating training.bin 700 / 6251
# creating training.bin 710 / 6251
# creating training.bin 720 / 6251
# creating training.bin 730 / 6251
# creating training.bin 740 / 6251
# creating training.bin 750 / 6251
# creating training.bin 760 / 6251
# creating training.bin 770 / 6251
# creating training.bin 780 / 6251
# creating training.bin 790 / 6251
# creating training.bin 800 / 6251
# creating training.bin 810 / 6251
# creating training.bin 820 / 6251
# creating training.bin 830 / 6251
# creating training.bin 840 / 6251
# creating training.bin 850 / 6251
# creating training.bin 860 / 6251
# creating training.bin 870 / 6251
# creating training.bin 880 / 6251
# creating training.bin 890 / 6251
# creating training.bin 900 / 6251
# creating training.bin 910 / 6251
# creating training.bin 920 / 6251
# creating training.bin 930 / 6251
# creating training.bin 940 / 6251
# creating training.bin 950 / 6251
# creating training.bin 960 / 6251
# creating training.bin 970 / 6251
# creating training.bin 980 / 6251
# creating training.bin 990 / 6251
# creating training.bin 1000 / 6251
# creating training.bin 1010 / 6251
# creating training.bin 1020 / 6251
# creating training.bin 1030 / 6251
# creating training.bin 1040 / 6251
# creating training.bin 1050 / 6251
# creating training.bin 1060 / 6251
# creating training.bin 1070 / 6251
# creating training.bin 1080 / 6251
# creating training.bin 1090 / 6251
# creating training.bin 1100 / 6251
# creating training.bin 1110 / 6251
# creating training.bin 1120 / 6251
# creating training.bin 1130 / 6251
# creating training.bin 1140 / 6251
# creating training.bin 1150 / 6251
# creating training.bin 1160 / 6251
# creating training.bin 1170 / 6251
# creating training.bin 1180 / 6251
# creating training.bin 1190 / 6251
# creating training.bin 1200 / 6251
# creating training.bin 1210 / 6251
# creating training.bin 1220 / 6251
# creating training.bin 1230 / 6251
# creating training.bin 1240 / 6251
# creating training.bin 1250 / 6251
# creating training.bin 1260 / 6251
# creating training.bin 1270 / 6251
# creating training.bin 1280 / 6251
# creating training.bin 1290 / 6251
# creating training.bin 1300 / 6251
# creating training.bin 1310 / 6251
# creating training.bin 1320 / 6251
# creating training.bin 1330 / 6251
# creating training.bin 1340 / 6251
# creating training.bin 1350 / 6251
# creating training.bin 1360 / 6251
# creating training.bin 1370 / 6251
# creating training.bin 1380 / 6251
# creating training.bin 1390 / 6251
# creating training.bin 1400 / 6251
# creating training.bin 1410 / 6251
# creating training.bin 1420 / 6251
# creating training.bin 1430 / 6251
# creating training.bin 1440 / 6251
# creating training.bin 1450 / 6251
# creating training.bin 1460 / 6251
# creating training.bin 1470 / 6251
# creating training.bin 1480 / 6251
# creating training.bin 1490 / 6251
# creating training.bin 1500 / 6251
# creating training.bin 1510 / 6251
# creating training.bin 1520 / 6251
# creating training.bin 1530 / 6251
# creating training.bin 1540 / 6251
# creating training.bin 1550 / 6251
# creating training.bin 1560 / 6251
# creating training.bin 1570 / 6251
# creating training.bin 1580 / 6251
# creating training.bin 1590 / 6251
# creating training.bin 1600 / 6251
# creating training.bin 1610 / 6251
# creating training.bin 1620 / 6251
# creating training.bin 1630 / 6251
# creating training.bin 1640 / 6251
# creating training.bin 1650 / 6251
# creating training.bin 1660 / 6251
# creating training.bin 1670 / 6251
# creating training.bin 1680 / 6251
# creating training.bin 1690 / 6251
# creating training.bin 1700 / 6251
# creating training.bin 1710 / 6251
# creating training.bin 1720 / 6251
# creating training.bin 1730 / 6251
# creating training.bin 1740 / 6251
# creating training.bin 1750 / 6251
# creating training.bin 1760 / 6251
# creating training.bin 1770 / 6251
# creating training.bin 1780 / 6251
# creating training.bin 1790 / 6251
# creating training.bin 1800 / 6251
# creating training.bin 1810 / 6251
# creating training.bin 1820 / 6251
# creating training.bin 1830 / 6251
# creating training.bin 1840 / 6251
# creating training.bin 1850 / 6251
# creating training.bin 1860 / 6251
# creating training.bin 1870 / 6251
# creating training.bin 1880 / 6251
# creating training.bin 1890 / 6251
# creating training.bin 1900 / 6251
# creating training.bin 1910 / 6251
# creating training.bin 1920 / 6251
# creating training.bin 1930 / 6251
# creating training.bin 1940 / 6251
# creating training.bin 1950 / 6251
# creating training.bin 1960 / 6251
# creating training.bin 1970 / 6251
# creating training.bin 1980 / 6251
# creating training.bin 1990 / 6251
# creating training.bin 2000 / 6251
# creating training.bin 2010 / 6251
# creating training.bin 2020 / 6251
# creating training.bin 2030 / 6251
# creating training.bin 2040 / 6251
# creating training.bin 2050 / 6251
# creating training.bin 2060 / 6251
# creating training.bin 2070 / 6251
# creating training.bin 2080 / 6251
# creating training.bin 2090 / 6251
# creating training.bin 2100 / 6251
# creating training.bin 2110 / 6251
# creating training.bin 2120 / 6251
# creating training.bin 2130 / 6251
# creating training.bin 2140 / 6251
# creating training.bin 2150 / 6251
# creating training.bin 2160 / 6251
# creating training.bin 2170 / 6251
# creating training.bin 2180 / 6251
# creating training.bin 2190 / 6251
# creating training.bin 2200 / 6251
# creating training.bin 2210 / 6251
# creating training.bin 2220 / 6251
# creating training.bin 2230 / 6251
# creating training.bin 2240 / 6251
# creating training.bin 2250 / 6251
# creating training.bin 2260 / 6251
# creating training.bin 2270 / 6251
# creating training.bin 2280 / 6251
# creating training.bin 2290 / 6251
# creating training.bin 2300 / 6251
# creating training.bin 2310 / 6251
# creating training.bin 2320 / 6251
# creating training.bin 2330 / 6251
# creating training.bin 2340 / 6251
# creating training.bin 2350 / 6251
# creating training.bin 2360 / 6251
# creating training.bin 2370 / 6251
# creating training.bin 2380 / 6251
# creating training.bin 2390 / 6251
# creating training.bin 2400 / 6251
# creating training.bin 2410 / 6251
# creating training.bin 2420 / 6251
# creating training.bin 2430 / 6251
# creating training.bin 2440 / 6251
# creating training.bin 2450 / 6251
# creating training.bin 2460 / 6251
# creating training.bin 2470 / 6251
# creating training.bin 2480 / 6251
# creating training.bin 2490 / 6251
# creating training.bin 2500 / 6251
# creating training.bin 2510 / 6251
# creating training.bin 2520 / 6251
# creating training.bin 2530 / 6251
# creating training.bin 2540 / 6251
# creating training.bin 2550 / 6251
# creating training.bin 2560 / 6251
# creating training.bin 2570 / 6251
# creating training.bin 2580 / 6251
# creating training.bin 2590 / 6251
# creating training.bin 2600 / 6251
# creating training.bin 2610 / 6251
# creating training.bin 2620 / 6251
# creating training.bin 2630 / 6251
# creating training.bin 2640 / 6251
# creating training.bin 2650 / 6251
# creating training.bin 2660 / 6251
# creating training.bin 2670 / 6251
# creating training.bin 2680 / 6251
# creating training.bin 2690 / 6251
# creating training.bin 2700 / 6251
# creating training.bin 2710 / 6251
# creating training.bin 2720 / 6251
# creating training.bin 2730 / 6251
# creating training.bin 2740 / 6251
# creating training.bin 2750 / 6251
# creating training.bin 2760 / 6251
# creating training.bin 2770 / 6251
# creating training.bin 2780 / 6251
# creating training.bin 2790 / 6251
# creating training.bin 2800 / 6251
# creating training.bin 2810 / 6251
# creating training.bin 2820 / 6251
# creating training.bin 2830 / 6251
# creating training.bin 2840 / 6251
# creating training.bin 2850 / 6251
# creating training.bin 2860 / 6251
# creating training.bin 2870 / 6251
# creating training.bin 2880 / 6251
# creating training.bin 2890 / 6251
# creating training.bin 2900 / 6251
# creating training.bin 2910 / 6251
# creating training.bin 2920 / 6251
# creating training.bin 2930 / 6251
# creating training.bin 2940 / 6251
# creating training.bin 2950 / 6251
# creating training.bin 2960 / 6251
# creating training.bin 2970 / 6251
# creating training.bin 2980 / 6251
# creating training.bin 2990 / 6251
# creating training.bin 3000 / 6251
# creating training.bin 3010 / 6251
# creating training.bin 3020 / 6251
# creating training.bin 3030 / 6251
# creating training.bin 3040 / 6251
# creating training.bin 3050 / 6251
# creating training.bin 3060 / 6251
# creating training.bin 3070 / 6251
# creating training.bin 3080 / 6251
# creating training.bin 3090 / 6251
# creating training.bin 3100 / 6251
# creating training.bin 3110 / 6251
# creating training.bin 3120 / 6251
# creating training.bin 3130 / 6251
# creating training.bin 3140 / 6251
# creating training.bin 3150 / 6251
# creating training.bin 3160 / 6251
# creating training.bin 3170 / 6251
# creating training.bin 3180 / 6251
# creating training.bin 3190 / 6251
# creating training.bin 3200 / 6251
# creating training.bin 3210 / 6251
# creating training.bin 3220 / 6251
# creating training.bin 3230 / 6251
# creating training.bin 3240 / 6251
# creating training.bin 3250 / 6251
# creating training.bin 3260 / 6251
# creating training.bin 3270 / 6251
# creating training.bin 3280 / 6251
# creating training.bin 3290 / 6251
# creating training.bin 3300 / 6251
# creating training.bin 3310 / 6251
# creating training.bin 3320 / 6251
# creating training.bin 3330 / 6251
# creating training.bin 3340 / 6251
# creating training.bin 3350 / 6251
# creating training.bin 3360 / 6251
# creating training.bin 3370 / 6251
# creating training.bin 3380 / 6251
# creating training.bin 3390 / 6251
# creating training.bin 3400 / 6251
# creating training.bin 3410 / 6251
# creating training.bin 3420 / 6251
# creating training.bin 3430 / 6251
# creating training.bin 3440 / 6251
# creating training.bin 3450 / 6251
# creating training.bin 3460 / 6251
# creating training.bin 3470 / 6251
# creating training.bin 3480 / 6251
# creating training.bin 3490 / 6251
# creating training.bin 3500 / 6251
# creating training.bin 3510 / 6251
# creating training.bin 3520 / 6251
# creating training.bin 3530 / 6251
# creating training.bin 3540 / 6251
# creating training.bin 3550 / 6251
# creating training.bin 3560 / 6251
# creating training.bin 3570 / 6251
# creating training.bin 3580 / 6251
# creating training.bin 3590 / 6251
# creating training.bin 3600 / 6251
# creating training.bin 3610 / 6251
# creating training.bin 3620 / 6251
# creating training.bin 3630 / 6251
# creating training.bin 3640 / 6251
# creating training.bin 3650 / 6251
# creating training.bin 3660 / 6251
# creating training.bin 3670 / 6251
# creating training.bin 3680 / 6251
# creating training.bin 3690 / 6251
# creating training.bin 3700 / 6251
# creating training.bin 3710 / 6251
# creating training.bin 3720 / 6251
# creating training.bin 3730 / 6251
# creating training.bin 3740 / 6251
# creating training.bin 3750 / 6251
# creating training.bin 3760 / 6251
# creating training.bin 3770 / 6251
# creating training.bin 3780 / 6251
# creating training.bin 3790 / 6251
# creating training.bin 3800 / 6251
# creating training.bin 3810 / 6251
# creating training.bin 3820 / 6251
# creating training.bin 3830 / 6251
# creating training.bin 3840 / 6251
# creating training.bin 3850 / 6251
# creating training.bin 3860 / 6251
# creating training.bin 3870 / 6251
# creating training.bin 3880 / 6251
# creating training.bin 3890 / 6251
# creating training.bin 3900 / 6251
# creating training.bin 3910 / 6251
# creating training.bin 3920 / 6251
# creating training.bin 3930 / 6251
# creating training.bin 3940 / 6251
# creating training.bin 3950 / 6251
# creating training.bin 3960 / 6251
# creating training.bin 3970 / 6251
# creating training.bin 3980 / 6251
# creating training.bin 3990 / 6251
# creating training.bin 4000 / 6251
# creating training.bin 4010 / 6251
# creating training.bin 4020 / 6251
# creating training.bin 4030 / 6251
# creating training.bin 4040 / 6251
# creating training.bin 4050 / 6251
# creating training.bin 4060 / 6251
# creating training.bin 4070 / 6251
# creating training.bin 4080 / 6251
# creating training.bin 4090 / 6251
# creating training.bin 4100 / 6251
# creating training.bin 4110 / 6251
# creating training.bin 4120 / 6251
# creating training.bin 4130 / 6251
# creating training.bin 4140 / 6251
# creating training.bin 4150 / 6251
# creating training.bin 4160 / 6251
# creating training.bin 4170 / 6251
# creating training.bin 4180 / 6251
# creating training.bin 4190 / 6251
# creating training.bin 4200 / 6251
# creating training.bin 4210 / 6251
# creating training.bin 4220 / 6251
# creating training.bin 4230 / 6251
# creating training.bin 4240 / 6251
# creating training.bin 4250 / 6251
# creating training.bin 4260 / 6251
# creating training.bin 4270 / 6251
# creating training.bin 4280 / 6251
# creating training.bin 4290 / 6251
# creating training.bin 4300 / 6251
# creating training.bin 4310 / 6251
# creating training.bin 4320 / 6251
# creating training.bin 4330 / 6251
# creating training.bin 4340 / 6251
# creating training.bin 4350 / 6251
# creating training.bin 4360 / 6251
# creating training.bin 4370 / 6251
# creating training.bin 4380 / 6251
# creating training.bin 4390 / 6251
# creating training.bin 4400 / 6251
# creating training.bin 4410 / 6251
# creating training.bin 4420 / 6251
# creating training.bin 4430 / 6251
# creating training.bin 4440 / 6251
# creating training.bin 4450 / 6251
# creating training.bin 4460 / 6251
# creating training.bin 4470 / 6251
# creating training.bin 4480 / 6251
# creating training.bin 4490 / 6251
# creating training.bin 4500 / 6251
# creating training.bin 4510 / 6251
# creating training.bin 4520 / 6251
# creating training.bin 4530 / 6251
# creating training.bin 4540 / 6251
# creating training.bin 4550 / 6251
# creating training.bin 4560 / 6251
# creating training.bin 4570 / 6251
# creating training.bin 4580 / 6251
# creating training.bin 4590 / 6251
# creating training.bin 4600 / 6251
# creating training.bin 4610 / 6251
# creating training.bin 4620 / 6251
# creating training.bin 4630 / 6251
# creating training.bin 4640 / 6251
# creating training.bin 4650 / 6251
# creating training.bin 4660 / 6251
# creating training.bin 4670 / 6251
# creating training.bin 4680 / 6251
# creating training.bin 4690 / 6251
# creating training.bin 4700 / 6251
# creating training.bin 4710 / 6251
# creating training.bin 4720 / 6251
# creating training.bin 4730 / 6251
# creating training.bin 4740 / 6251
# creating training.bin 4750 / 6251
# creating training.bin 4760 / 6251
# creating training.bin 4770 / 6251
# creating training.bin 4780 / 6251
# creating training.bin 4790 / 6251
# creating training.bin 4800 / 6251
# creating training.bin 4810 / 6251
# creating training.bin 4820 / 6251
# creating training.bin 4830 / 6251
# creating training.bin 4840 / 6251
# creating training.bin 4850 / 6251
# creating training.bin 4860 / 6251
# creating training.bin 4870 / 6251
# creating training.bin 4880 / 6251
# creating training.bin 4890 / 6251
# creating training.bin 4900 / 6251
# creating training.bin 4910 / 6251
# creating training.bin 4920 / 6251
# creating training.bin 4930 / 6251
# creating training.bin 4940 / 6251
# creating training.bin 4950 / 6251
# creating training.bin 4960 / 6251
# creating training.bin 4970 / 6251
# creating training.bin 4980 / 6251
# creating training.bin 4990 / 6251
# creating training.bin 5000 / 6251
# creating training.bin 5010 / 6251
# creating training.bin 5020 / 6251
# creating training.bin 5030 / 6251
# creating training.bin 5040 / 6251
# creating training.bin 5050 / 6251
# creating training.bin 5060 / 6251
# creating training.bin 5070 / 6251
# creating training.bin 5080 / 6251
# creating training.bin 5090 / 6251
# creating training.bin 5100 / 6251
# creating training.bin 5110 / 6251
# creating training.bin 5120 / 6251
# creating training.bin 5130 / 6251
# creating training.bin 5140 / 6251
# creating training.bin 5150 / 6251
# creating training.bin 5160 / 6251
# creating training.bin 5170 / 6251
# creating training.bin 5180 / 6251
# creating training.bin 5190 / 6251
# creating training.bin 5200 / 6251
# creating training.bin 5210 / 6251
# creating training.bin 5220 / 6251
# creating training.bin 5230 / 6251
# creating training.bin 5240 / 6251
# Error loading id: Q7551241 HTTP Error 404: Not Found
# creating training.bin 5250 / 6251
# creating training.bin 5260 / 6251
# creating training.bin 5270 / 6251
# creating training.bin 5280 / 6251
# creating training.bin 5290 / 6251
# creating training.bin 5300 / 6251
# creating training.bin 5310 / 6251
# creating training.bin 5320 / 6251
# creating training.bin 5330 / 6251
# creating training.bin 5340 / 6251
# creating training.bin 5350 / 6251
# creating training.bin 5360 / 6251
# creating training.bin 5370 / 6251
# creating training.bin 5380 / 6251
# creating training.bin 5390 / 6251
# creating training.bin 5400 / 6251
# creating training.bin 5410 / 6251
# creating training.bin 5420 / 6251
# creating training.bin 5430 / 6251
# creating training.bin 5440 / 6251
# creating training.bin 5450 / 6251
# creating training.bin 5460 / 6251
# creating training.bin 5470 / 6251
# creating training.bin 5480 / 6251
# creating training.bin 5490 / 6251
# creating training.bin 5500 / 6251
# creating training.bin 5510 / 6251
# creating training.bin 5520 / 6251
# creating training.bin 5530 / 6251
# creating training.bin 5540 / 6251
# creating training.bin 5550 / 6251
# creating training.bin 5560 / 6251
# creating training.bin 5570 / 6251
# creating training.bin 5580 / 6251
# creating training.bin 5590 / 6251
# creating training.bin 5600 / 6251
# creating training.bin 5610 / 6251
# creating training.bin 5620 / 6251
# creating training.bin 5630 / 6251
# creating training.bin 5640 / 6251
# creating training.bin 5650 / 6251
# creating training.bin 5660 / 6251
# creating training.bin 5670 / 6251
# creating training.bin 5680 / 6251
# creating training.bin 5690 / 6251
# creating training.bin 5700 / 6251
# creating training.bin 5710 / 6251
# creating training.bin 5720 / 6251
# creating training.bin 5730 / 6251
# creating training.bin 5740 / 6251
# creating training.bin 5750 / 6251
# creating training.bin 5760 / 6251
# creating training.bin 5770 / 6251
# creating training.bin 5780 / 6251
# creating training.bin 5790 / 6251
# creating training.bin 5800 / 6251
# creating training.bin 5810 / 6251
# creating training.bin 5820 / 6251
# creating training.bin 5830 / 6251
# creating training.bin 5840 / 6251
# creating training.bin 5850 / 6251
# creating training.bin 5860 / 6251
# creating training.bin 5870 / 6251
# creating training.bin 5880 / 6251
# creating training.bin 5890 / 6251
# creating training.bin 5900 / 6251
# creating training.bin 5910 / 6251
# creating training.bin 5920 / 6251
# creating training.bin 5930 / 6251
# creating training.bin 5940 / 6251
# creating training.bin 5950 / 6251
# creating training.bin 5960 / 6251
# creating training.bin 5970 / 6251
# creating training.bin 5980 / 6251
# creating training.bin 5990 / 6251
# creating training.bin 6000 / 6251
# creating training.bin 6010 / 6251
# creating training.bin 6020 / 6251
# creating training.bin 6030 / 6251
# creating training.bin 6040 / 6251
# creating training.bin 6050 / 6251
# creating training.bin 6060 / 6251
# creating training.bin 6070 / 6251
# creating training.bin 6080 / 6251
# creating training.bin 6090 / 6251
# creating training.bin 6100 / 6251
# creating training.bin 6110 / 6251
# creating training.bin 6120 / 6251
# creating training.bin 6130 / 6251
# creating training.bin 6140 / 6251
# creating training.bin 6150 / 6251
# creating training.bin 6160 / 6251
# creating training.bin 6170 / 6251
# creating training.bin 6180 / 6251
# creating training.bin 6190 / 6251
# creating training.bin 6200 / 6251
# creating training.bin 6210 / 6251
# creating training.bin 6220 / 6251
# creating training.bin 6230 / 6251
# creating training.bin 6240 / 6251
# creating training.bin 6250 / 6251
# creating validation.bin 10 / 300
# creating validation.bin 20 / 300
# creating validation.bin 30 / 300
# creating validation.bin 40 / 300
# creating validation.bin 50 / 300
# creating validation.bin 60 / 300
# creating validation.bin 70 / 300
# creating validation.bin 80 / 300
# creating validation.bin 90 / 300
# creating validation.bin 100 / 300
# creating validation.bin 110 / 300
# creating validation.bin 120 / 300
# creating validation.bin 130 / 300
# creating validation.bin 140 / 300
# creating validation.bin 150 / 300
# creating validation.bin 160 / 300
# creating validation.bin 170 / 300
# creating validation.bin 180 / 300
# creating validation.bin 190 / 300
# creating validation.bin 200 / 300
# creating validation.bin 210 / 300
# creating validation.bin 220 / 300
# creating validation.bin 230 / 300
# creating validation.bin 240 / 300
# creating validation.bin 250 / 300
# creating validation.bin 260 / 300
# creating validation.bin 270 / 300
# creating validation.bin 280 / 300
# creating validation.bin 290 / 300
# creating validation.bin 300 / 300
# dumping training.bin
# dumping validation.bin

# %% [markdown]
# If the dump files `training.bin` and `validation.bin` are present, the instance is build from the dump.
# Without transformers we're going to process manually fields and texts.
# In the following code:
# 1. dictionaries are created to produce frequency vectors
# 2. GloVe pretrained embeddings are applied to the descriptions
# 3. the labels are mapped to numbers
# 4. Category and subcategories are mapped to a single scalar value for each entity - pandas is used to group the ids of the subcategories by the category
#
# The result is a singleton `ProcessedDataset` that extends the base `NLPDataset`
# providing also the `ProcessedEntity`s of the corresponding (base) `Entity`.
#
# Finally the result of the processing is dumped and can be reused to the next run

# %%
# !pip install torchtext==0.6.0
# Out:
# Collecting torchtext==0.6.0
#   Downloading torchtext-0.6.0-py3-none-any.whl.metadata (6.3 kB)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.11/dist-packages (from torchtext==0.6.0) (4.67.1)
# Requirement already satisfied: requests in /usr/local/lib/python3.11/dist-packages (from torchtext==0.6.0) (2.32.3)
# Requirement already satisfied: torch in /usr/local/lib/python3.11/dist-packages (from torchtext==0.6.0) (2.6.0+cu124)
# Requirement already satisfied: numpy in /usr/local/lib/python3.11/dist-packages (from torchtext==0.6.0) (2.0.2)
# Requirement already satisfied: six in /usr/local/lib/python3.11/dist-packages (from torchtext==0.6.0) (1.17.0)
# Requirement already satisfied: sentencepiece in /usr/local/lib/python3.11/dist-packages (from torchtext==0.6.0) (0.2.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests->torchtext==0.6.0) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests->torchtext==0.6.0) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests->torchtext==0.6.0) (2.4.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests->torchtext==0.6.0) (2025.1.31)
# Requirement already satisfied: filelock in /usr/local/lib/python3.11/dist-packages (from torch->torchtext==0.6.0) (3.18.0)
# Requirement already satisfied: typing-extensions>=4.10.0 in /usr/local/lib/python3.11/dist-packages (from torch->torchtext==0.6.0) (4.13.2)
# Requirement already satisfied: networkx in /usr/local/lib/python3.11/dist-packages (from torch->torchtext==0.6.0) (3.4.2)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.11/dist-packages (from torch->torchtext==0.6.0) (3.1.6)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.11/dist-packages (from torch->torchtext==0.6.0) (2025.3.0)
# Collecting nvidia-cuda-nvrtc-cu12==12.4.127 (from torch->torchtext==0.6.0)
#   Downloading nvidia_cuda_nvrtc_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cuda-runtime-cu12==12.4.127 (from torch->torchtext==0.6.0)
#   Downloading nvidia_cuda_runtime_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cuda-cupti-cu12==12.4.127 (from torch->torchtext==0.6.0)
#   Downloading nvidia_cuda_cupti_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cudnn-cu12==9.1.0.70 (from torch->torchtext==0.6.0)
#   Downloading nvidia_cudnn_cu12-9.1.0.70-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cublas-cu12==12.4.5.8 (from torch->torchtext==0.6.0)
#   Downloading nvidia_cublas_cu12-12.4.5.8-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cufft-cu12==11.2.1.3 (from torch->torchtext==0.6.0)
#   Downloading nvidia_cufft_cu12-11.2.1.3-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-curand-cu12==10.3.5.147 (from torch->torchtext==0.6.0)
#   Downloading nvidia_curand_cu12-10.3.5.147-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cusolver-cu12==11.6.1.9 (from torch->torchtext==0.6.0)
#   Downloading nvidia_cusolver_cu12-11.6.1.9-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cusparse-cu12==12.3.1.170 (from torch->torchtext==0.6.0)
#   Downloading nvidia_cusparse_cu12-12.3.1.170-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.6.2 in /usr/local/lib/python3.11/dist-packages (from torch->torchtext==0.6.0) (0.6.2)
# Requirement already satisfied: nvidia-nccl-cu12==2.21.5 in /usr/local/lib/python3.11/dist-packages (from torch->torchtext==0.6.0) (2.21.5)
# Requirement already satisfied: nvidia-nvtx-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch->torchtext==0.6.0) (12.4.127)
# Collecting nvidia-nvjitlink-cu12==12.4.127 (from torch->torchtext==0.6.0)
#   Downloading nvidia_nvjitlink_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Requirement already satisfied: triton==3.2.0 in /usr/local/lib/python3.11/dist-packages (from torch->torchtext==0.6.0) (3.2.0)
# Requirement already satisfied: sympy==1.13.1 in /usr/local/lib/python3.11/dist-packages (from torch->torchtext==0.6.0) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.11/dist-packages (from sympy==1.13.1->torch->torchtext==0.6.0) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.11/dist-packages (from jinja2->torch->torchtext==0.6.0) (3.0.2)
# Downloading torchtext-0.6.0-py3-none-any.whl (64 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 64.2/64.2 kB 2.7 MB/s eta 0:00:00
# Downloading nvidia_cublas_cu12-12.4.5.8-py3-none-manylinux2014_x86_64.whl (363.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 4.7 MB/s eta 0:00:00
# Downloading nvidia_cuda_cupti_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (13.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 59.4 MB/s eta 0:00:00
# Downloading nvidia_cuda_nvrtc_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (24.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.6/24.6 MB 33.5 MB/s eta 0:00:00
# Downloading nvidia_cuda_runtime_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (883 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 883.7/883.7 kB 40.7 MB/s eta 0:00:00
# Downloading nvidia_cudnn_cu12-9.1.0.70-py3-none-manylinux2014_x86_64.whl (664.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 751.7 kB/s eta 0:00:00
# Downloading nvidia_cufft_cu12-11.2.1.3-py3-none-manylinux2014_x86_64.whl (211.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 3.6 MB/s eta 0:00:00
# Downloading nvidia_curand_cu12-10.3.5.147-py3-none-manylinux2014_x86_64.whl (56.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 12.9 MB/s eta 0:00:00
# Downloading nvidia_cusolver_cu12-11.6.1.9-py3-none-manylinux2014_x86_64.whl (127.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.9/127.9 MB 6.8 MB/s eta 0:00:00
# Downloading nvidia_cusparse_cu12-12.3.1.170-py3-none-manylinux2014_x86_64.whl (207.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.5/207.5 MB 2.2 MB/s eta 0:00:00
# Downloading nvidia_nvjitlink_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (21.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.1/21.1 MB 79.3 MB/s eta 0:00:00
# Installing collected packages: nvidia-nvjitlink-cu12, nvidia-curand-cu12, nvidia-cufft-cu12, nvidia-cuda-runtime-cu12, nvidia-cuda-nvrtc-cu12, nvidia-cuda-cupti-cu12, nvidia-cublas-cu12, nvidia-cusparse-cu12, nvidia-cudnn-cu12, nvidia-cusolver-cu12, torchtext
#   Attempting uninstall: nvidia-nvjitlink-cu12
#     Found existing installation: nvidia-nvjitlink-cu12 12.5.82
#     Uninstalling nvidia-nvjitlink-cu12-12.5.82:
#       Successfully uninstalled nvidia-nvjitlink-cu12-12.5.82
#   Attempting uninstall: nvidia-curand-cu12
#     Found existing installation: nvidia-curand-cu12 10.3.6.82
#     Uninstalling nvidia-curand-cu12-10.3.6.82:
#       Successfully uninstalled nvidia-curand-cu12-10.3.6.82
#   Attempting uninstall: nvidia-cufft-cu12
#     Found existing installation: nvidia-cufft-cu12 11.2.3.61
#     Uninstalling nvidia-cufft-cu12-11.2.3.61:
#       Successfully uninstalled nvidia-cufft-cu12-11.2.3.61
#   Attempting uninstall: nvidia-cuda-runtime-cu12
#     Found existing installation: nvidia-cuda-runtime-cu12 12.5.82
#     Uninstalling nvidia-cuda-runtime-cu12-12.5.82:
#       Successfully uninstalled nvidia-cuda-runtime-cu12-12.5.82
#   Attempting uninstall: nvidia-cuda-nvrtc-cu12
#     Found existing installation: nvidia-cuda-nvrtc-cu12 12.5.82
#     Uninstalling nvidia-cuda-nvrtc-cu12-12.5.82:
#       Successfully uninstalled nvidia-cuda-nvrtc-cu12-12.5.82
#   Attempting uninstall: nvidia-cuda-cupti-cu12
#     Found existing installation: nvidia-cuda-cupti-cu12 12.5.82
#     Uninstalling nvidia-cuda-cupti-cu12-12.5.82:
#       Successfully uninstalled nvidia-cuda-cupti-cu12-12.5.82
#   Attempting uninstall: nvidia-cublas-cu12
#     Found existing installation: nvidia-cublas-cu12 12.5.3.2
#     Uninstalling nvidia-cublas-cu12-12.5.3.2:
#       Successfully uninstalled nvidia-cublas-cu12-12.5.3.2
#   Attempting uninstall: nvidia-cusparse-cu12
#     Found existing installation: nvidia-cusparse-cu12 12.5.1.3
#     Uninstalling nvidia-cusparse-cu12-12.5.1.3:
#       Successfully uninstalled nvidia-cusparse-cu12-12.5.1.3
#   Attempting uninstall: nvidia-cudnn-cu12
#     Found existing installation: nvidia-cudnn-cu12 9.3.0.75
#     Uninstalling nvidia-cudnn-cu12-9.3.0.75:
#       Successfully uninstalled nvidia-cudnn-cu12-9.3.0.75
#   Attempting uninstall: nvidia-cusolver-cu12
#     Found existing installation: nvidia-cusolver-cu12 11.6.3.83
#     Uninstalling nvidia-cusolver-cu12-11.6.3.83:
#       Successfully uninstalled nvidia-cusolver-cu12-11.6.3.83
# Successfully installed nvidia-cublas-cu12-12.4.5.8 nvidia-cuda-cupti-cu12-12.4.127 nvidia-cuda-nvrtc-cu12-12.4.127 nvidia-cuda-runtime-cu12-12.4.127 nvidia-cudnn-cu12-9.1.0.70 nvidia-cufft-cu12-11.2.1.3 nvidia-curand-cu12-10.3.5.147 nvidia-cusolver-cu12-11.6.1.9 nvidia-cusparse-cu12-12.3.1.170 nvidia-nvjitlink-cu12-12.4.127 torchtext-0.6.0

# %%
import collections, nltk, string
import pandas as pd
from torchtext.vocab import GloVe
from nltk.corpus import stopwords
from nltk.stem import WordNetLemmatizer
from torch.utils.data import IterableDataset

# %%
def type_vector(base_type):
    vector = np.zeros(1, dtype=np.float32)
    if base_type == 'entity':
        vector[0] = vector[0] + 1
    return vector

def label_to_number(label):
    if label == 'cultural agnostic':
        return 0
    if label == 'cultural representative':
        return 1
    if label == 'cultural exclusive':
        return 2
    raise ValueError('label not suppoerted: ' + label)

class ProcessedEntity:
    def __init__(self, base: Entity, desc_text, wiki_text):
        self.base_entity = base.entity_id + ": " + base.name
        # processed fields
        self.desc_text = desc_text
        self.wiki_text = wiki_text
        self.labels_text = base.labels
        self.descriptions_text = base.descriptions
        self.aliases_text = base.aliases
        self.pages_text = base.wikipedia_pages
        # Using map to denote a Python dictionary,
        # since the dictionary is already use for a word (term) dictionary
        self.claims_map = base.claims
        self.subcategory = base.subcategory
        self.category = base.category

        # build later (then the dictionaries are finalized)
        self.desc_vector = None
        self.wiki_vector = None
        self.labels_vector = None
        self.descriptions_vector = None
        self.aliases_vector = None
        self.pages_vector = None
        self.claims_vector = None
        # it includes implicitly the category
        # since the subcategory values have been ordered by category
        self.subcategory_vector = None
        # in this case we can assume that we have only two types (entity vs concept)
        self.type_vector = type_vector(base.type)
        self.desc_glove_vector = None
        self.output_label = label_to_number(base.label)

    def __str__(self):
        return self.base_entity + " < " + str(len(self.desc_text)) + ", " + str(len(self.wiki_text)) + " >"

    def dataset_item(self):
        return {
            "desc" : self.desc_vector,
            "wiki" : self.wiki_vector,
            "labels" : self.labels_vector,
            "descriptions" : self.descriptions_vector,
            "aliases" : self.aliases_vector,
            "pages" : self.pages_vector,
            "claims" : self.claims_vector,
            "category" : self.subcategory_vector,
            "type" : self.type_vector,
            "desc_glove" : self.desc_glove_vector,
            "output_label" : self.output_label,
            "base" : self.base_entity
        }

class CategoryTable:
    def __init__(self):
        self.subcategories_entered = {}  # to avoid duplicates
        self.subcategories = []
        self.categories = []
        self.subcategory_to_id = None  # computed on build

    def include(self, processed_entity: ProcessedEntity):
        if processed_entity.subcategory in self.subcategories_entered:
            return
        self.subcategories_entered[processed_entity.subcategory] = True
        self.subcategories.append(processed_entity.subcategory)
        self.categories.append(processed_entity.category)

    def build(self):
        data = {
            'subcategory': self.subcategories,
            'category': self.categories
        }
        df = pd.DataFrame(data)
        df = df.sort_values('category')
        print(df.to_markdown())
        self.subcategory_to_id = {row["subcategory"]: index for index, (_, row) in enumerate(df.iterrows())}

    def subcat_to_vector(self, subcategory):
        vector = np.zeros(1, dtype=np.float32)
        vector[0] = vector[0] + self.subcategory_to_id[subcategory]
        return vector

    def length(self):
        return len(self.subcategory_to_id)

class Dictionary:
    def __init__(self):
        self.occurrences = []
        self.unk_token = None
        self.word_to_id = None

    def include(self, tokenized_text):
        self.occurrences.extend(tokenized_text)

    def build(self, max_vocab_size, unk_token):
        self.unk_token = unk_token
        counter = collections.Counter(self.occurrences)
        self.word_to_id = {key: index for index, (key, _) in enumerate(counter.most_common(max_vocab_size - 1))}
        assert unk_token not in self.word_to_id
        self.word_to_id[unk_token] = max_vocab_size - 1
        self.occurrences = None # free memory space

    def build_no_limits(self):
        counter = collections.Counter(self.occurrences)
        self.word_to_id = {key: index for index, (key, _) in enumerate(counter.most_common())}
        self.occurrences = None # free memory space

    def length(self):
        return len(self.word_to_id)

    def words_to_vector(self, words):
        vector = np.zeros(self.length(), dtype=np.float32)
        for word in words:
            if word == self.unk_token:
                continue
            if word in self.word_to_id:
                vector[self.word_to_id[word]] = vector[self.word_to_id[word]] + 1
        return vector

    # Using map to denote a Python dictionary,
    # since the dictionary is already use for a word (term) dictionary
    def map_to_vector(self, dictionary):
        vector = np.zeros(self.length(), dtype=np.float32)
        for word, freq in dictionary.items():
            if word == self.unk_token:
                continue
            if word in self.word_to_id:
                vector[self.word_to_id[word]] = freq
        return vector

PAD_TOKEN = '<PAD>'

class GloveProcessing:
    def __init__(self, context_size):
        self.glove = GloVe(name='6B', dim=100)
        self.context_size = context_size

    def words_to_vect(self, words):
        return self.glove.get_vecs_by_tokens(self.tokens(words)).view(-1)

    def tokens(self, words):
        return words[:self.context_size] + [PAD_TOKEN]*(self.context_size-len(words))

UNK = '<UNK>' # the token to be used for out of vocabulary words
DESC_VOCAB_SIZE = 4_000
WIKI_VOCAB_SIZE = 10_000
GLOVE_EMBEDDING_SIZE = 20

class Dictionaries:
    def __init__(self):
        # descriptions and wiki text words are in 2 different vector spaces
        self.desc = Dictionary()
        self.wiki = Dictionary()
        # we use the same languages keys dictionaries for:
        # labels_text, descriptions_text, aliases_text, pages_text
        self.languages = Dictionary()
        self.claims = Dictionary()
        self.category_table = CategoryTable()
        # extra add glove embeddings
        self.glove_desc = GloveProcessing(GLOVE_EMBEDDING_SIZE)

    def include(self, processed_entity: ProcessedEntity):
        self.desc.include(processed_entity.desc_text)
        self.wiki.include(processed_entity.wiki_text)
        self.languages.include(processed_entity.labels_text)
        self.languages.include(processed_entity.descriptions_text)
        self.languages.include(processed_entity.aliases_text)
        self.languages.include(processed_entity.pages_text)
        self.claims.include(list(processed_entity.claims_map.keys()))
        self.category_table.include(processed_entity)

    def build(self):
        self.desc.build(DESC_VOCAB_SIZE, UNK)
        self.wiki.build(WIKI_VOCAB_SIZE, UNK)
        self.claims.build_no_limits()
        # those guys are not too large: so we can not limit them
        self.languages.build_no_limits()
        self.category_table.build()

    def finalize(self, processed_entity: ProcessedEntity):
        processed_entity.desc_vector = self.desc.words_to_vector(processed_entity.desc_text)
        processed_entity.wiki_vector = self.wiki.words_to_vector(processed_entity.wiki_text)
        processed_entity.labels_vector = self.languages.words_to_vector(processed_entity.labels_text)
        processed_entity.descriptions_vector = self.languages.words_to_vector(processed_entity.descriptions_text)
        processed_entity.aliases_vector = self.languages.words_to_vector(processed_entity.aliases_text)
        processed_entity.pages_vector = self.languages.words_to_vector(processed_entity.pages_text)
        processed_entity.claims_vector = self.claims.map_to_vector(processed_entity.claims_map)
        processed_entity.subcategory_vector = self.category_table.subcat_to_vector(processed_entity.subcategory)
        processed_entity.desc_glove_vector = self.glove_desc.words_to_vect(processed_entity.desc_text)

class IterableEntities(IterableDataset):
    def __init__(self, processed_entities: list[ProcessedEntity]):
        self.processed_entities = processed_entities

    def __iter__(self):
        for entity in self.processed_entities:
            yield entity.dataset_item()

    def __len__(self):
        return len(self.processed_entities)

TRAINING_PROC_FILE_NAME = "training-proc.bin"
VALIDATION_PROC_FILE_NAME = "validation-proc.bin"

def text_process(text, stop):
    result = []
    if text is None:
        return result
    for sentence in nltk.sent_tokenize(text.lower()):
        result.extend([WordNetLemmatizer().lemmatize(i) for i in nltk.word_tokenize(sentence) if i not in stop])
    return result

def create_processed(entity, dictionaries, stop):
    description_tokenized = text_process(entity.description, stop)
    wiki_text_tokenized = text_process(entity.wiki_text, stop)
    result = ProcessedEntity(entity, description_tokenized, wiki_text_tokenized)
    dictionaries.include(result)
    return result

class ProcessedDataset(NLPDataset):
    def __init__(self, training_limit=None, validation_limit=None, force_reload=False):
        super().__init__(training_limit, validation_limit, force_reload)
        if not (os.path.exists(TRAINING_PROC_FILE_NAME)) or not (os.path.exists(VALIDATION_PROC_FILE_NAME)) or force_reload:
            self.processed_training_set, self.processed_validation_set = self.processing()
            dump(TRAINING_PROC_FILE_NAME, self.processed_training_set)
            dump(VALIDATION_PROC_FILE_NAME, self.processed_validation_set)
        else:
            # by default load the dataset from a local dump
            self.processed_training_set = load(TRAINING_PROC_FILE_NAME)
            self.processed_validation_set = load(VALIDATION_PROC_FILE_NAME)

    def processing(self):
        nltk.download('stopwords')
        nltk.download('wordnet')
        nltk.download('punkt_tab')
        stop = set(stopwords.words('english') + list(string.punctuation) + ['==', "''", '``', "'s", '==='])
        print("processing the data")
        dictionaries = Dictionaries()
        # from the base data, add a list of processed entities
        print("training set text processing started")
        processed_training_set = []
        for index, entity in enumerate(self.training_set):
            processed_training_set.append(create_processed(entity, dictionaries, stop))
            if (index+1) % 100 == 0:
                print("training set processed", index+1, "entities")
        print("training set text processing ended")
        print("validation set text processing started")
        processed_validation_set = []
        for index, entity in enumerate(self.validation_set):
            processed_validation_set.append(create_processed(entity, dictionaries, stop))
            if (index+1) % 100 == 0:
                print("validation set processed", index+1, "entities")
        print("validation set text processing ended")
        print("building dictionaries")
        # when we've collected all the words for the two spaces, we can build them
        dictionaries.build()
        print("text to vector started")
        # build the vectors from the texts
        for entity in processed_training_set:
            dictionaries.finalize(entity)
        for entity in processed_validation_set:
            dictionaries.finalize(entity)
        print("text to vector finished")
        return processed_training_set, processed_validation_set

    def training(self):
        return IterableEntities(self.processed_training_set)

    def validation(self):
        return IterableEntities(self.processed_validation_set)

# %%
dataset = ProcessedDataset()
# Out:
# loading training.bin
# loading validation.bin
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data] Downloading package punkt_tab to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt_tab.zip.
# processing the data
# .vector_cache/glove.6B.zip: 862MB [02:39, 5.41MB/s]
# 100%|█████████▉| 399999/400000 [00:32<00:00, 12283.52it/s]
# training set text processing started
# training set processed 100 entities
# training set processed 200 entities
# training set processed 300 entities
# training set processed 400 entities
# training set processed 500 entities
# training set processed 600 entities
# training set processed 700 entities
# training set processed 800 entities
# training set processed 900 entities
# training set processed 1000 entities
# training set processed 1100 entities
# training set processed 1200 entities
# training set processed 1300 entities
# training set processed 1400 entities
# training set processed 1500 entities
# training set processed 1600 entities
# training set processed 1700 entities
# training set processed 1800 entities
# training set processed 1900 entities
# training set processed 2000 entities
# training set processed 2100 entities
# training set processed 2200 entities
# training set processed 2300 entities
# training set processed 2400 entities
# training set processed 2500 entities
# training set processed 2600 entities
# training set processed 2700 entities
# training set processed 2800 entities
# training set processed 2900 entities
# training set processed 3000 entities
# training set processed 3100 entities
# training set processed 3200 entities
# training set processed 3300 entities
# training set processed 3400 entities
# training set processed 3500 entities
# training set processed 3600 entities
# training set processed 3700 entities
# training set processed 3800 entities
# training set processed 3900 entities
# training set processed 4000 entities
# training set processed 4100 entities
# training set processed 4200 entities
# training set processed 4300 entities
# training set processed 4400 entities
# training set processed 4500 entities
# training set processed 4600 entities
# training set processed 4700 entities
# training set processed 4800 entities
# training set processed 4900 entities
# training set processed 5000 entities
# training set processed 5100 entities
# training set processed 5200 entities
# training set processed 5300 entities
# training set processed 5400 entities
# training set processed 5500 entities
# training set processed 5600 entities
# training set processed 5700 entities
# training set processed 5800 entities
# training set processed 5900 entities
# training set processed 6000 entities
# training set processed 6100 entities
# training set processed 6200 entities
# training set text processing ended
# validation set text processing started
# validation set processed 100 entities
# validation set processed 200 entities
# validation set processed 300 entities
# validation set text processing ended
# building dictionaries
# |     | subcategory              | category                |
# |----:|:-------------------------|:------------------------|
# |  71 | architectural style      | architecture            |
# |   3 | building                 | architecture            |
# |  15 | architectural structure  | architecture            |
# |  52 | architect                | architecture            |
# |  51 | building material        | architecture            |
# |  27 | construction             | architecture            |
# |  29 | tree                     | biology                 |
# |  76 | biologist                | biology                 |
# |  84 | plant                    | biology                 |
# |  42 | organism                 | biology                 |
# |  40 | animal                   | biology                 |
# |  93 | fish                     | biology                 |
# |  97 | bookstore                | books                   |
# |  50 | non-fiction writer       | books                   |
# | 109 | religious book           | books                   |
# |   6 | book                     | books                   |
# |  33 | animated film            | comics and anime        |
# |  78 | comics artist            | comics and anime        |
# |  19 | animation studio         | comics and anime        |
# |  95 | manga                    | comics and anime        |
# |  12 | animation technique      | comics and anime        |
# |   2 | comics                   | comics and anime        |
# | 105 | fashion trend            | fashion                 |
# |  67 | clothing                 | fashion                 |
# |  79 | model                    | fashion                 |
# |  60 | traditional costume      | fashion                 |
# |  48 | designer                 | fashion                 |
# |  58 | textile                  | fashion                 |
# | 108 | acting style             | films                   |
# |  81 | film director            | films                   |
# |  13 | film festival            | films                   |
# |   0 | film                     | films                   |
# | 100 | film genre               | films                   |
# |  24 | film producer            | films                   |
# |  14 | drink                    | food                    |
# |  72 | dish                     | food                    |
# | 101 | cooking technique        | food                    |
# |  92 | ingredient               | food                    |
# | 103 | cook                     | food                    |
# |  99 | food                     | food                    |
# |  83 | mountain                 | geography               |
# |  49 | geographic location      | geography               |
# |   4 | city                     | geography               |
# | 104 | environment              | geography               |
# |  45 | neighborhood             | geography               |
# |  30 | river                    | geography               |
# |  63 | tradition                | gestures and habits     |
# | 107 | body language            | gestures and habits     |
# |  69 | gesture                  | gestures and habits     |
# | 110 | mores                    | gestures and habits     |
# |  37 | greeting                 | gestures and habits     |
# |  32 | ritual                   | gestures and habits     |
# |  77 | monument                 | history                 |
# |   5 | historical event         | history                 |
# |  25 | museum                   | history                 |
# |  75 | historian                | history                 |
# |  64 | archive                  | history                 |
# |  23 | poet                     | literature              |
# |  74 | literary genre           | literature              |
# |  89 | poetry                   | literature              |
# |  47 | publisher                | literature              |
# |  86 | literary award           | literature              |
# |  28 | writer                   | literature              |
# | 106 | writing style            | literature              |
# |   7 | film studio              | media                   |
# |  91 | streaming service        | media                   |
# |  90 | production company       | media                   |
# |  11 | television               | media                   |
# |   9 | media company            | media                   |
# |  10 | magazine                 | media                   |
# |  88 | record label             | music                   |
# |  55 | musician                 | music                   |
# |  39 | musical profession       | music                   |
# |  41 | music genre              | music                   |
# |  16 | music festival           | music                   |
# |   1 | musical group            | music                   |
# |  87 | theatrical genre         | performing arts         |
# |  46 | actor                    | performing arts         |
# |  80 | choreographer            | performing arts         |
# |  54 | theatrical director      | performing arts         |
# |  61 | dance                    | performing arts         |
# |  65 | folk dance               | performing arts         |
# |   8 | philosophical movement   | philosophy and religion |
# |  62 | religion                 | philosophy and religion |
# |  66 | religious movement       | philosophy and religion |
# |  22 | religious leader         | philosophy and religion |
# |  73 | philosopher              | philosophy and religion |
# |  59 | philosophy               | philosophy and religion |
# |  98 | government               | politics                |
# |  20 | politician               | politics                |
# |  43 | political party          | politics                |
# |  31 | government agency        | politics                |
# |  38 | law                      | politics                |
# |  36 | policy                   | politics                |
# |  21 | sports team              | sports                  |
# |  34 | recurring sporting event | sports                  |
# |  68 | sports equipment         | sports                  |
# |  35 | sports club              | sports                  |
# |  70 | sport                    | sports                  |
# |  53 | athlete                  | sports                  |
# |  26 | automobile manufacturer  | transportation          |
# |  44 | mode of transport        | transportation          |
# | 102 | transport                | transportation          |
# |  56 | station                  | transportation          |
# |  57 | transport company        | transportation          |
# |  94 | art movement             | visual arts             |
# |  85 | artist                   | visual arts             |
# |  18 | painting                 | visual arts             |
# |  17 | art gallery              | visual arts             |
# |  82 | photographer             | visual arts             |
# |  96 | visual arts              | visual arts             |
# | 111 | happening                | visual arts             |
# text to vector started
# text to vector finished
# dumping training-proc.bin
# dumping validation-proc.bin

# %%
import torch, csv, statistics
import matplotlib.pyplot as plt
from torch import nn, optim
from torch.utils.data import DataLoader
from huggingface_hub import PyTorchModelHubMixin
from tqdm.auto import tqdm

# %% [markdown]
# We arrived at the very heart of the No-Trasformer solution: the model!
# We want to use all the data source from the dataset, the WikiData and WikiPedia pages. Since those guys have a very different original dimentions we the code idea is to scale them in a pre training layer before to produce the combined vector that is passed in input the classifier (a FF network).

# %%
def rescale_vector_layer(params):
    in_features, out_features = params
    # frequency vector fields rescaling (applying also a RuLU individually):
    return nn.Sequential(nn.Linear(in_features, out_features), nn.ReLU())

class MultiModalModel(nn.Module, PyTorchModelHubMixin,
                      repo_url="fax4ever/culturalitems-no-transformer",
                      pipeline_tag="text-classification",
                      license="apache-2.0"):
    def __init__(self, params, device) -> None:
        super(MultiModalModel, self).__init__()
        self.device = device
        # individual input layers for frequency vectors
        self.desc = rescale_vector_layer(params['desc']).to(device)
        self.wiki = rescale_vector_layer(params['wiki']).to(device)
        self.labels = rescale_vector_layer(params['labels']).to(device)
        self.descriptions = rescale_vector_layer(params['descriptions']).to(device)
        self.aliases = rescale_vector_layer(params['aliases']).to(device)
        self.pages = rescale_vector_layer(params['pages']).to(device)
        self.claims = rescale_vector_layer(params['claims']).to(device)
        # individual input layers for scalar value
        self.category = nn.Linear(params['category_dim'], params['category_scale']).to(device)
        self.type_proj = nn.Linear(params['type_dim'], params['type_scale']).to(device)
        # glove
        self.desc_glove = rescale_vector_layer(params['desc_glove']).to(device)
        # common classifier
        self.classifier = nn.Sequential(
            nn.Linear(params['total_scale'], params['hidden_layers']),
            nn.ReLU(),
            nn.Dropout(params['dropout']),
            nn.Linear(params['hidden_layers'], 3)
        ).to(device)

    def forward(self, dataset_items):
        desc_feat = self.desc(dataset_items['desc'].to(self.device))
        wiki_feat = self.wiki(dataset_items['wiki'].to(self.device))
        labels_feat = self.labels(dataset_items['labels'].to(self.device))
        descriptions_feat = self.descriptions(dataset_items['descriptions'].to(self.device))
        aliases_feat = self.aliases(dataset_items['aliases'].to(self.device))
        pages_feat = self.pages(dataset_items['pages'].to(self.device))
        claims_feat = self.claims(dataset_items['claims'].to(self.device))
        category_feat = self.category(dataset_items['category'].to(self.device))
        type_feat = self.type_proj(dataset_items['type'].to(self.device))
        desc_glove_feat = self.desc_glove(dataset_items['desc_glove'].to(self.device))
        combined = torch.cat([desc_feat, desc_glove_feat, wiki_feat, labels_feat, descriptions_feat, aliases_feat, pages_feat,
                              claims_feat, category_feat, type_feat], dim=1)
        return self.classifier(combined)

# %% [markdown]
# Scaled dimensions and other hyper paramters are configured from a single class:

# %%
class NLPHyperParams:
    def __init__(self, example: ProcessedEntity):
        # original vector dimensions
        self.desc_dim = example.desc_vector.shape[0]
        self.wiki_dim = example.wiki_vector.shape[0]
        self.labels_dim = example.labels_vector.shape[0]
        self.descriptions_dim = example.descriptions_vector.shape[0]
        self.aliases_dim = example.aliases_vector.shape[0]
        self.pages_dim = example.pages_vector.shape[0]
        self.claims_dim = example.claims_vector.shape[0]
        self.category_dim = 1 # scalar
        self.type_dim = 1 # scalar
        self.desc_glove_dim = example.desc_glove_vector.shape[0]

        # scaled dimensions
        self.desc_scale = 64*2
        self.wiki_scale = 64*2
        self.labels_scale = 8*2
        self.descriptions_scale = 8*2
        self.aliases_scale = 8*2
        self.pages_scale = 8*2
        self.claims_scale = 16*2
        self.category_scale = 8*2
        self.type_scale = 8*2
        self.desc_glove_scale = 64*2

        # common classifier
        self.hidden_layers = 128*2
        self.dropout = 0.15
        self.learning_rate = 1e-3
        self.weight_decay = 1e-2
        self.epochs = 20 # manual early stopping
        self.batch_size = 32

    def desc(self):
        return self.desc_dim, self.desc_scale
    def wiki(self):
        return self.wiki_dim, self.wiki_scale
    def labels(self):
        return self.labels_dim, self.labels_scale
    def descriptions(self):
        return self.descriptions_dim, self.descriptions_scale
    def aliases(self):
        return self.aliases_dim, self.aliases_scale
    def pages(self):
        return self.pages_dim, self.pages_scale
    def claims(self):
        return self.claims_dim, self.claims_scale
    def desc_glove(self):
        return self.desc_glove_dim, self.desc_glove_scale
    def total_scale(self):
        return self.desc_scale + self.wiki_scale + self.labels_scale + self.descriptions_scale + self.aliases_scale + \
            self.pages_scale + self.claims_scale + self.category_scale + self.type_scale + self.desc_glove_scale

    def params(self):
        return {
            'desc': self.desc(),
            'wiki': self.wiki(),
            'labels': self.labels(),
            'descriptions': self.descriptions(),
            'aliases': self.aliases(),
            'pages': self.pages(),
            'claims': self.claims(),
            'desc_glove': self.desc_glove(),
            'total_scale': self.total_scale(),
            'category_dim': self.category_dim,
            'category_scale': self.category_scale,
            'type_dim': self.type_dim,
            'type_scale': self.type_scale,
            'hidden_layers': self.hidden_layers,
            'dropout': self.dropout
        }

# %% [markdown]
# In the training we collect the accuracy and the loss for the training and the validation set at each epoch.

# %%
def compute_accuracy(predictions, labels):
    discrete_predictions = predictions.detach().clone()
    discrete_predictions = discrete_predictions.argmax(dim=1)
    return torch.mean(torch.Tensor([1 if p==l else 0 for p, l in list(zip(discrete_predictions.view(-1), labels.view(-1)))])).item()

class NLPTrainer:
    def __init__(self, model: MultiModalModel, optimizer, loss_function, device, params: NLPHyperParams):
        self.model = model
        self.optimizer = optimizer
        self.loss_function = loss_function
        self.device = device
        self.params = params

    def train(self, train_dataset, validation_dataset):
        print('Training...')
        train_loss = []
        train_accuracy = []
        valid_loss = []
        valid_accuracy = []

        for epoch in range(self.params.epochs):
            print(' Epoch {:03d}'.format(epoch + 1))
            epoch_loss = 0.0
            epoch_accuracy = 0.0
            for step, dataset_items in tqdm(enumerate(train_dataset), desc="Batch", leave=False):
                targets = dataset_items['output_label'].to(self.device)
                self.optimizer.zero_grad()
                predictions = self.model(dataset_items)
                sample_loss = self.loss_function(predictions, targets)
                sample_loss.backward()
                self.optimizer.step()
                epoch_loss += sample_loss.tolist()
                epoch_accuracy += compute_accuracy(predictions, targets)
            avg_epoch_loss = epoch_loss / len(train_dataset)
            avg_epoch_accuracy = epoch_accuracy / len(train_dataset)
            print('  [E: {:2d}] train loss = {:0.4f} | train accuracy = {:0.4f}'.format(epoch, avg_epoch_loss, avg_epoch_accuracy))
            valid_loss_epoch, valid_accuracy_epoch = self.evaluate(validation_dataset)
            print('  [E: {:2d}] valid loss = {:0.4f} | eval accuracy =. {:0.4f}'.format(epoch, valid_loss_epoch, valid_accuracy_epoch))
            train_loss.append(avg_epoch_loss)
            train_accuracy.append(avg_epoch_accuracy)
            valid_loss.append(valid_loss_epoch)
            valid_accuracy.append(valid_accuracy_epoch)
        print('... Done!')
        avg_epoch_loss = statistics.mean(train_loss)
        avg_epoch_accuracy = statistics.mean(train_accuracy)
        return {
            "avg_epoch_loss": avg_epoch_loss,
            "avg_epoch_accuracy": avg_epoch_accuracy,
            "train_loss": train_loss,
            "train_accuracy": train_accuracy,
            "valid_loss": valid_loss,
            "valid_accuracy": valid_accuracy
        }

    def evaluate(self, valid_dataset):
        valid_loss = 0.0
        validation_accuracy = 0.0
        # no gradient updates here, we are at inference time!
        with torch.no_grad():
            for step, dataset_items in tqdm(enumerate(valid_dataset), desc="Batch", leave=False):
                targets = dataset_items['output_label'].to(self.device)
                predictions = self.model(dataset_items)
                sample_loss = self.loss_function(predictions, targets)
                valid_loss += sample_loss.tolist()
                validation_accuracy += compute_accuracy(predictions, targets)
        return valid_loss / len(valid_dataset), validation_accuracy / len(valid_dataset)

    def predict(self, x):
        return self.model(x).tolist()

# %% [markdown]
# Putting all tougher, present and optionally publish the result:

# %%
hyper_params = NLPHyperParams(dataset.processed_training_set[0])
training_dataloader = DataLoader(dataset.training(), batch_size=hyper_params.batch_size)
validation_dataloader = DataLoader(dataset.validation(), batch_size=hyper_params.batch_size)
device = 'cuda' if torch.cuda.is_available() else 'cpu'
print("using device:", device)
model = MultiModalModel(hyper_params.params(), device)
optimizer = optim.AdamW(model.parameters(), lr=hyper_params.learning_rate, weight_decay=hyper_params.weight_decay)
criterion = nn.CrossEntropyLoss()
trainer = NLPTrainer(model, optimizer, criterion, device, hyper_params)
history = trainer.train(training_dataloader, validation_dataloader)
print(history)

print("### Summary")
print("average loss", history["avg_epoch_loss"])
print("average accuracy", history["avg_epoch_accuracy"])

plt.title("MSE Loss - Plot")
plt.plot(history["train_loss"], label="training loss")
plt.plot(history["valid_loss"], label="validation loss")
plt.legend()
plt.show()

plt.title("Accuracy - Plot")
plt.plot(history["train_accuracy"], label="training accuracy")
plt.plot(history["valid_accuracy"], label="validation accuracy")
plt.legend()
plt.show()
# Out:
# using device: cpu
# Training...
#  Epoch 001
# Batch: 0it [00:00, ?it/s]
#   [E:  0] train loss = 0.7360 | train accuracy = 0.6987
# Batch: 0it [00:00, ?it/s]
#   [E:  0] valid loss = 0.7403 | eval accuracy =. 0.6948
#  Epoch 002
# Batch: 0it [00:00, ?it/s]
#   [E:  1] train loss = 0.3695 | train accuracy = 0.8592
# Batch: 0it [00:00, ?it/s]
#   [E:  1] valid loss = 0.9729 | eval accuracy =. 0.6896
#  Epoch 003
# Batch: 0it [00:00, ?it/s]
#   [E:  2] train loss = 0.1702 | train accuracy = 0.9407
# Batch: 0it [00:00, ?it/s]
#   [E:  2] valid loss = 1.3767 | eval accuracy =. 0.7042
#  Epoch 004
# Batch: 0it [00:00, ?it/s]
#   [E:  3] train loss = 0.0953 | train accuracy = 0.9684
# Batch: 0it [00:00, ?it/s]
#   [E:  3] valid loss = 1.5129 | eval accuracy =. 0.7010
#  Epoch 005
# Batch: 0it [00:00, ?it/s]
#   [E:  4] train loss = 0.0300 | train accuracy = 0.9904
# Batch: 0it [00:00, ?it/s]
#   [E:  4] valid loss = 1.6671 | eval accuracy =. 0.7156
#  Epoch 006
# Batch: 0it [00:00, ?it/s]
#   [E:  5] train loss = 0.0194 | train accuracy = 0.9947
# Batch: 0it [00:00, ?it/s]
#   [E:  5] valid loss = 2.0362 | eval accuracy =. 0.6948
#  Epoch 007
# Batch: 0it [00:00, ?it/s]
#   [E:  6] train loss = 0.0182 | train accuracy = 0.9962
# Batch: 0it [00:00, ?it/s]
#   [E:  6] valid loss = 1.8862 | eval accuracy =. 0.7073
#  Epoch 008
# Batch: 0it [00:00, ?it/s]
#   [E:  7] train loss = 0.0144 | train accuracy = 0.9971
# Batch: 0it [00:00, ?it/s]
#   [E:  7] valid loss = 2.1637 | eval accuracy =. 0.7031
#  Epoch 009
# Batch: 0it [00:00, ?it/s]
#   [E:  8] train loss = 0.0022 | train accuracy = 0.9997
# Batch: 0it [00:00, ?it/s]
#   [E:  8] valid loss = 2.2409 | eval accuracy =. 0.7073
#  Epoch 010
# Batch: 0it [00:00, ?it/s]
#   [E:  9] train loss = 0.0009 | train accuracy = 0.9997
# Batch: 0it [00:00, ?it/s]
#   [E:  9] valid loss = 2.3156 | eval accuracy =. 0.7042
#  Epoch 011
# Batch: 0it [00:00, ?it/s]
#   [E: 10] train loss = 0.0006 | train accuracy = 0.9998
# Batch: 0it [00:00, ?it/s]
#   [E: 10] valid loss = 2.3551 | eval accuracy =. 0.7073
#  Epoch 012
# Batch: 0it [00:00, ?it/s]
#   [E: 11] train loss = 0.0006 | train accuracy = 0.9997
# Batch: 0it [00:00, ?it/s]
#   [E: 11] valid loss = 2.4783 | eval accuracy =. 0.7104
#  Epoch 013
# Batch: 0it [00:00, ?it/s]
#   [E: 12] train loss = 0.0005 | train accuracy = 0.9997
# Batch: 0it [00:00, ?it/s]
#   [E: 12] valid loss = 2.5568 | eval accuracy =. 0.7010
#  Epoch 014
# Batch: 0it [00:00, ?it/s]
#   [E: 13] train loss = 0.0004 | train accuracy = 0.9998
# Batch: 0it [00:00, ?it/s]
#   [E: 13] valid loss = 2.5022 | eval accuracy =. 0.7010
#  Epoch 015
# Batch: 0it [00:00, ?it/s]
#   [E: 14] train loss = 0.0057 | train accuracy = 0.9997
# Batch: 0it [00:00, ?it/s]
#   [E: 14] valid loss = 2.4942 | eval accuracy =. 0.6948
#  Epoch 016
# Batch: 0it [00:00, ?it/s]
#   [E: 15] train loss = 0.0010 | train accuracy = 0.9997
# Batch: 0it [00:00, ?it/s]
#   [E: 15] valid loss = 2.7247 | eval accuracy =. 0.7010
#  Epoch 017
# Batch: 0it [00:00, ?it/s]
#   [E: 16] train loss = 0.0830 | train accuracy = 0.9794
# Batch: 0it [00:00, ?it/s]
#   [E: 16] valid loss = 2.1244 | eval accuracy =. 0.7312
#  Epoch 018
# Batch: 0it [00:00, ?it/s]
#   [E: 17] train loss = 0.0590 | train accuracy = 0.9834
# Batch: 0it [00:00, ?it/s]
#   [E: 17] valid loss = 2.2493 | eval accuracy =. 0.7240
#  Epoch 019
# Batch: 0it [00:00, ?it/s]
#   [E: 18] train loss = 0.0221 | train accuracy = 0.9935
# Batch: 0it [00:00, ?it/s]
#   [E: 18] valid loss = 2.8533 | eval accuracy =. 0.7104
#  Epoch 020
# Batch: 0it [00:00, ?it/s]
#   [E: 19] train loss = 0.0072 | train accuracy = 0.9981
# Batch: 0it [00:00, ?it/s]
#   [E: 19] valid loss = 2.6547 | eval accuracy =. 0.7188
# ... Done!
# {'avg_epoch_loss': 0.08181646964600037, 'avg_epoch_accuracy': 0.9698804209122852, 'train_loss': [0.736025441057828, 0.36947049766931, 0.17017554485106043, 0.0953344391713546, 0.030007332575353627, 0.01944985319660562, 0.018245233860305198, 0.014398785078142561, 0.0022028193420830615, 0.0009494181403847413, 0.0005554695574258459, 0.0006471737325385647, 0.0005088308767342972, 0.00039176450596243033, 0.005742853864141895, 0.0010489792295040425, 0.08295796003413411, 0.058976032311893876, 0.022088164583553352, 0.007152799281691247], 'train_accuracy': [0.6986607142857143, 0.8592155612244898, 0.9406887755102041, 0.9684311224489796, 0.9904336734693877, 0.9947385204081632, 0.9961734693877551, 0.9971301020408163, 0.9996811224489796, 0.9996811224489796, 0.9998405612244898, 0.9996811224489796, 0.9996811224489796, 0.9998405612244898, 0.9996811224489796, 0.9996811224489796, 0.9794005100824394, 0.9834183673469388, 0.9934630102040817, 0.9980867346938775], 'valid_loss': [0.7403225600719452, 0.9729458034038544, 1.3767055869102478, 1.5128504037857056, 1.667110276222229, 2.036248707771301, 1.886229658126831, 2.163692557811737, 2.2408942699432375, 2.3156418442726134, 2.3551027894020082, 2.47829133272171, 2.5567609310150146, 2.50216064453125, 2.4941609621047975, 2.7247424840927126, 2.124395823478699, 2.2492799162864685, 2.8533199191093446, 2.6547115564346315], 'valid_accuracy': [0.6947916686534882, 0.6895833313465118, 0.7041666686534882, 0.7010416686534882, 0.715625, 0.6947916686534882, 0.7072916686534881, 0.703125, 0.7072916686534881, 0.7041666686534882, 0.7072916686534881, 0.7104166686534882, 0.7010416686534882, 0.7010416686534882, 0.6947916686534882, 0.7010416686534882, 0.73125, 0.7239583313465119, 0.7104166686534882, 0.71875]}
# ### Summary
# average loss 0.08181646964600037
# average accuracy 0.9698804209122852

# %%
# uncomment to publish it
# model.save_pretrained("culturalitems-no-transformer")
# model.push_to_hub("fax4ever/culturalitems-no-transformer", token=userdata.get('HF_TOKEN'))
